# %%
x = 34 - 23 # A comment.
y = "Hello" # Another one.
z = 3.45
if z == 3.45 or y == "Hello":
   x = x + 1 
   y = y + "World" # String concat.
print(x)
print(y)
# Out:
# 12
# HelloWorld

# %%
x, y = 2, 3
print(x)
print(y)
# Out:
# 2
# 3

# %%
tu = (23, 'abc', 4.56, (2,3), 'def')

# %%
li = ["abc", 34, 4.34, 23]

# %%
print(li)
# Out:
# ['abc', 34, 4.34, 23]
